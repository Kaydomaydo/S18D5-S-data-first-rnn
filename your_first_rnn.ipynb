# %% [markdown]
# # İlk Tekrarlayan Sinir Ağınız (RNN)

# %% [markdown]
# 🙌 RNN'lere hoş geldiniz! Önceki derste görseller (uzamsal veri) ile ilgilenmek için CNN'leri kullandıktan sonra, şimdi zamanla ilgili veriler (***zamansal veri***) ile ilgileneceksiniz.
#
# 🎯 Bu ısınma challenge'ının hedefleri:
#
# 1. Zamansal verinin ne olduğunu anlamak
# 2. İlk Tekrarlayan Sinir Ağlarınızı oluşturmak

# %% [markdown]
# _Not: Google Colab kullanmaya gerek yok ❌_

# %% [markdown]
# ## (1) 📚 Veri seti

# %% [markdown]
# _Uyarı: bu bölümde kendiniz kod yazmanıza gerek yok, dikkatli okuyun ve hücreleri çalıştırın. RNN ve LSTM modellerine odaklanmanızı istiyoruz, Python sorularına değil_ 😉

# %% [markdown]
# 🔢 Bir şirketteki çalışanlar hakkında bazı verilere erişimimiz olduğunu düşünün.

# %%
import numpy as np

X = np.load('X.npy')
y = np.load('y.npy')

# %%
X.shape, y.shape
# Out:
# ((25000, 10, 3), (25000,))

# %% [markdown]
# ☝️ Veri seti **25.000 çalışanın istihdam durumunun yıllar içindeki gelişimini** tanımlar: her sekans 10 ardışık yıla karşılık gelir ve her yıl 3 bileşenden oluşan bir iş durumunu açıklar
# - maaş,
# - sorumluluğundaki kişi sayısı,
# - şirketin büyüklüğü.
#
# 🕵🏻 Veri setini biraz daha iyi anlamak için ilk çalışanın verilerine bakalım.

# %%
import pandas as pd

employee_0 = pd.DataFrame(X[0],
                          columns=['salary',
                                   'responsibility',
                                   'company_size'])
round(employee_0,2)
# Out:
#    salary  responsibility  company_size
# 0    0.80           10.73         102.0
# 1    0.50           10.73         102.0
# 2    0.60           10.73         102.0
# 3    0.71           10.73         130.0
# 4    0.94           10.73         130.0
# 5    1.05           10.73         130.0
# 6    1.12           32.00         108.0
# 7    4.87           32.00         108.0
# 8    4.97           33.00         108.0
# 9    5.20           39.00         108.0

# %% [markdown]
# 🎯 Bu challenge'ın amacı, geçmiş gözlemlere dayanarak bu 25.000 çalışanın her biri için 11. yıldaki aylık maaşı tahmin etmektir.

# %%
# For example, the first employee earns 6.499 k USD per month
# during the 11th year at the company
y[0]
# Out:
# np.float64(6.499)

# %% [markdown]
# 📈 Maaşların, sorumluluklarındaki kişi sayısının ve şirket büyüklüğünün yıllar içindeki gelişimini daha iyi anlamanız için aşağıdaki hücreyi çalıştırabilirsiniz. Bu üç değişken arasında görsel olarak bazı korelasyonlar tespit edebiliyor musunuz?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

number_of_employees = len(X)

### Choosing random employees
##### As the employees are selected randomly, feel free to re-run this cell a few times !

number_of_randomly_selected_employees = 5

random_selection = np.random.randint(0,
                                     number_of_employees,
                                     number_of_randomly_selected_employees)


### Plotting data for the selected employees

plt.title('Salary')
for r in random_selection:
    plt.plot(X[r, :, 0],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('# People responsibile for')
for r in random_selection:
    plt.plot(X[r, :, 1],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('Company sizes')
for r in random_selection:
    plt.plot(X[r, :, 2],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# 🕵🏻 **Veri Keşfi** 🕵🏻 Gözlemlerin değişkenliğini daha iyi anlamak için şunların dağılımına bakın:
# * 10. yıldaki tüm maaşlar,
# * sorumluluğundaki kişiler,
# * ve şirket büyüklükleri

# %%
import seaborn as sns

plt.title("Salaries on the 10th year")
sns.histplot(X[:, -1, 0].flatten()) # all the employees, last year, feature #0 = salaries
plt.show()

plt.title("# of people under someone's responsibility")
sns.histplot(X[:, :, 1].flatten()) # all the employees, all the years, feature #1 = responsabilities
plt.show()

plt.title("Company size")
sns.histplot(X[:, :, 2].flatten()) # all the employees, all the years, feature #2 = company size
plt.show()

# %% [markdown]
# ✂️ **Tutma yöntemi** Veri setini eğitim ve test setine ayıralım (80/20)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# Notice that we are train_test_splitting the 25 000 employees!

# %% [markdown]
# ## (2) 💻 Basit bir RNN

# %% [markdown]
# 🤗 Artık bu şirketin veri setiyle tanıştığınıza göre, ilk Tekrarlayan Sinir Ağınızı oluşturacaksınız. Basit bir mimariyle başlayalım.

# %% [markdown]
# ❓ **Soru** ❓ Şunları içeren bir model yazın:
# - Eğitim setine uyarlanmış bir ***Normalization*** katmanı
# - 20 *ünite* içeren bir ***SimpleRNN*** katmanı (Tekrarlayan Katman için aktivasyon fonksiyonu olarak `tanh`'ın daha uygun olduğunu unutmayın)
# - 10 nöronlu bir ***Dense*** katmanı
# - Görevinize özel bir ***Dense*** katmanı (= maaş ***tahmini*** yapmak için)
#
# 👩🏻‍🏫 Unutmayın: İlk katmandan önce `keras.Input` eklemeyi unutmayın.

# %%
from keras import Sequential, Input
from keras.layers import Dense, SimpleRNN, Flatten, Normalization

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
inputs=keras.Input(shape=(None,3))
normalizer = layers.Normalization(axis=-1)
x=normalizer(inputs)
x=layers.SimpleRNN(20,activation='tanh')(x)
x=layers.Dense(10,activation='softmax')(x)
outputs=layers.Dense(1)(x)
model=keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mse',metrics=['mae'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, None, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization_1 (Normalization) │ (None, None, 3)        │             7 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 20)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 708 (2.77 KB)
#  Trainable params: 701 (2.74 KB)
#  Non-trainable params: 7 (32.00 B)

# %% [markdown]
# ❓ **Soru**: RNN'inizde kaç tane eğitilebilir parametre var ❓

# %%
701
# Out:
# 701

# %% [markdown]
# ❓ **Soru** ❓ Parametre sayısını elle yeniden hesaplamaya çalışın.

# %% [markdown]
# > CEVABINIZI BURAYA YAZIN

# %% [markdown]
# <details>
#     <summary><i>Cevap</i></summary>
#
#
# - <u> Normalizasyon Katmanı</u>:
#     - Bu katman normalize edilecek $\color{red}{n_x = 3} $ özelliğe (maaş, sorumluluk, şirket büyüklüğü) sahiptir. Her biri için <font color=blue>_ortalama_</font> ve <font color=blue>_standart_sapma_</font> hesaplanması gerekir. Yani $\color{red}{n_x = 3} \times \color{blue}{2} = 6$ eğitilemez parametremiz vardır. 7. parametre başlangıçta 0'a ayarlanmış bir bias'tır.
#
# - <u> Tekrarlayan Katman</u>:
#     - Eğer $\color{green}{n_h = 20} $ RNN ünitesi $\color{red}{n_x = 3} $ özelliğe paralel uygulanırsa, Tekrarlayan Katman $\color{green}{n_h}(\color{green}{n_h} + \color{red}{n_x} + 1) = \color{green}{20} \times (\color{green}{20}+\color{red}{3}+1) = \color{green}{20} \times 24 = 480$ eğitilebilir parametreye sahiptir.
#     - Bu sayının her sekansın uzunluğundan (burada 10 gün) *bağımsız* olduğuna dikkat edin
#
# - <u> Yoğun Katman</u>:
#     - $\color{green}{n_h = 20} $ RNN ünitesi ve $1$ bias ile başlayarak, 10 nöron kullanarak, Yoğun Katman $ (\color{green}{20}+1) \times 10 = 21 \times 10 = 210$ parametreye sahiptir
#
# - <u> Tahmin Yoğun Katmanı</u>:
#     - $10$ nöron ve $1$ bias ile başlayarak, 11. maaşı tahmin etmek için 1 nöron kullanarak, Tahmin Yoğun Katmanı $ (10+1) \times 1 = 11 \times 1 = 11$ parametreye sahiptir
#
# </details>

# %% [markdown]
# ❓ **Soru** ❓ Modelinizi derleyin. RNN için ***rmsprop*** optimizer'ını (*adam* yerine) kullanmanızı öneriyoruz.

# %%
model.compile(
    optimizer='rmsprop',            
    loss='mean_squared_error',     
    metrics=['mean_absolute_error']  
)

# %% [markdown]
# ❓ **Sorular** ❓
#
# * Modelinizi eğitim veri setinizde eğitin:
#     * %20'lik bir Doğrulama Bölümü kullanın
#     * ve sabır $= 5 $ olan bir Erken Durdurma Kriteri kullanın
# * Test setindeki performansınızı değerlendirin

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop=EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)
history = model.fit(X_train, y_train,
                    validation_split=0.2,
                    epochs=100,
                    batch_size=32,
                    callbacks=[early_stop],
                    verbose=1)
# Out:
# Epoch 1/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 51.6124 - mean_absolute_error: 4.2065 - val_loss: 34.9149 - val_mean_absolute_error: 3.3727
# Epoch 2/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 44.0539 - mean_absolute_error: 3.3717 - val_loss: 29.5889 - val_mean_absolute_error: 2.8378
# Epoch 3/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 39.0676 - mean_absolute_error: 3.1326 - val_loss: 26.1222 - val_mean_absolute_error: 2.8220
# Epoch 4/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 35.7181 - mean_absolute_error: 3.1148 - val_loss: 22.8066 - val_mean_absolute_error: 2.3949
# Epoch 5/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 31.4851 - mean_absolute_error: 2.5200 - val_loss: 19.5482 - val_mean_absolute_error: 2.0110
# Epoch 6/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 27.8603 - mean_absolute_error: 2.1587 - val_loss: 16.8905 - val_mean_absolute_error: 1.7250
# Epoch 7/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 24.9967 - mean_absolute_error: 1.9319 - val_loss: 14.7313 - val_mean_absolute_error: 1.5505
# Epoch 8/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 22.5190 - mean_absolute_error: 1.7716 - val_loss: 12.9353 - val_mean_absolute_error: 1.4140
# Epoch 9/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 20.4236 - mean_absolute_error: 1.6441 - val_loss: 11.4337 - val_mean_absolute_error: 1.3174
# Epoch 10/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 18.6392 - mean_absolute_error: 1.5355 - val_loss: 10.2298 - val_mean_absolute_error: 1.2414
# Epoch 11/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 17.0793 - mean_absolute_error: 1.4406 - val_loss: 9.2043 - val_mean_absolute_error: 1.1685
# Epoch 12/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 15.7175 - mean_absolute_error: 1.3531 - val_loss: 8.2464 - val_mean_absolute_error: 1.0904
# Epoch 13/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 14.5384 - mean_absolute_error: 1.2802 - val_loss: 7.4491 - val_mean_absolute_error: 1.0169
# Epoch 14/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 13.4788 - mean_absolute_error: 1.2159 - val_loss: 6.9764 - val_mean_absolute_error: 1.0263
# Epoch 15/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 12.5590 - mean_absolute_error: 1.1615 - val_loss: 6.1530 - val_mean_absolute_error: 0.9164
# Epoch 16/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 11.6868 - mean_absolute_error: 1.1102 - val_loss: 5.5846 - val_mean_absolute_error: 0.8864
# Epoch 17/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 10.9557 - mean_absolute_error: 1.0598 - val_loss: 5.1799 - val_mean_absolute_error: 0.8720
# Epoch 18/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 10.2930 - mean_absolute_error: 1.0171 - val_loss: 4.8160 - val_mean_absolute_error: 0.8275
# Epoch 19/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 9.6580 - mean_absolute_error: 0.9778 - val_loss: 4.3530 - val_mean_absolute_error: 0.7861
# Epoch 20/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 9.1191 - mean_absolute_error: 0.9385 - val_loss: 3.9914 - val_mean_absolute_error: 0.7351
# Epoch 21/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 8.6276 - mean_absolute_error: 0.9055 - val_loss: 3.8526 - val_mean_absolute_error: 0.7395
# Epoch 22/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 8.1581 - mean_absolute_error: 0.8714 - val_loss: 3.6040 - val_mean_absolute_error: 0.7030
# Epoch 23/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 7.7930 - mean_absolute_error: 0.8425 - val_loss: 3.2749 - val_mean_absolute_error: 0.6951
# Epoch 24/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 7.4203 - mean_absolute_error: 0.8145 - val_loss: 3.0796 - val_mean_absolute_error: 0.6619
# Epoch 25/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 7.0997 - mean_absolute_error: 0.7911 - val_loss: 2.8515 - val_mean_absolute_error: 0.6236
# Epoch 26/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 6.7993 - mean_absolute_error: 0.7797 - val_loss: 3.1418 - val_mean_absolute_error: 0.6885
# Epoch 27/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 6.5409 - mean_absolute_error: 0.7645 - val_loss: 2.7267 - val_mean_absolute_error: 0.6276
# Epoch 28/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 6.3196 - mean_absolute_error: 0.7520 - val_loss: 2.6039 - val_mean_absolute_error: 0.6359
# Epoch 29/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 6.0728 - mean_absolute_error: 0.7364 - val_loss: 2.4524 - val_mean_absolute_error: 0.5864
# Epoch 30/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 5.8809 - mean_absolute_error: 0.7244 - val_loss: 2.3702 - val_mean_absolute_error: 0.5832
# Epoch 31/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 5.6606 - mean_absolute_error: 0.7089 - val_loss: 2.3813 - val_mean_absolute_error: 0.6080
# Epoch 32/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 5.4829 - mean_absolute_error: 0.6953 - val_loss: 2.0807 - val_mean_absolute_error: 0.5468
# Epoch 33/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 5.3025 - mean_absolute_error: 0.6884 - val_loss: 2.0796 - val_mean_absolute_error: 0.5584
# Epoch 34/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 5.1390 - mean_absolute_error: 0.6723 - val_loss: 1.9794 - val_mean_absolute_error: 0.5351
# Epoch 35/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 5.0195 - mean_absolute_error: 0.6707 - val_loss: 1.9220 - val_mean_absolute_error: 0.5720
# Epoch 36/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 4.8145 - mean_absolute_error: 0.6522 - val_loss: 1.8064 - val_mean_absolute_error: 0.5383
# Epoch 37/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 4.7385 - mean_absolute_error: 0.6584 - val_loss: 2.0172 - val_mean_absolute_error: 0.5893
# Epoch 38/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 4.6216 - mean_absolute_error: 0.6396 - val_loss: 1.7750 - val_mean_absolute_error: 0.5884
# Epoch 39/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 4.5110 - mean_absolute_error: 0.6296 - val_loss: 2.1832 - val_mean_absolute_error: 0.6409
# Epoch 40/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 4.4097 - mean_absolute_error: 0.6259 - val_loss: 1.6839 - val_mean_absolute_error: 0.4916
# Epoch 41/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 4.2391 - mean_absolute_error: 0.6069 - val_loss: 1.7808 - val_mean_absolute_error: 0.6247
# Epoch 42/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 4.1822 - mean_absolute_error: 0.6070 - val_loss: 2.7289 - val_mean_absolute_error: 0.7022
# Epoch 43/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 4.0576 - mean_absolute_error: 0.6086 - val_loss: 1.4901 - val_mean_absolute_error: 0.4821
# Epoch 44/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 3.9631 - mean_absolute_error: 0.5931 - val_loss: 1.4738 - val_mean_absolute_error: 0.5023
# Epoch 45/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 3.8932 - mean_absolute_error: 0.5917 - val_loss: 1.3706 - val_mean_absolute_error: 0.4398
# Epoch 46/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.7947 - mean_absolute_error: 0.5818 - val_loss: 1.3310 - val_mean_absolute_error: 0.4877
# Epoch 47/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 3.7261 - mean_absolute_error: 0.5835 - val_loss: 1.3514 - val_mean_absolute_error: 0.4612
# Epoch 48/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 3.6515 - mean_absolute_error: 0.5691 - val_loss: 1.1719 - val_mean_absolute_error: 0.4124
# Epoch 49/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 3.5747 - mean_absolute_error: 0.5679 - val_loss: 1.6095 - val_mean_absolute_error: 0.5934
# Epoch 50/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.5311 - mean_absolute_error: 0.5728 - val_loss: 1.3197 - val_mean_absolute_error: 0.5184
# Epoch 51/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 3.4553 - mean_absolute_error: 0.5722 - val_loss: 1.2595 - val_mean_absolute_error: 0.5213
# Epoch 52/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 3.4364 - mean_absolute_error: 0.5704 - val_loss: 1.1199 - val_mean_absolute_error: 0.4299
# Epoch 53/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.4200 - mean_absolute_error: 0.5785 - val_loss: 1.2752 - val_mean_absolute_error: 0.4840
# Epoch 54/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 3.3530 - mean_absolute_error: 0.5759 - val_loss: 1.3530 - val_mean_absolute_error: 0.5298
# Epoch 55/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 3.3032 - mean_absolute_error: 0.5735 - val_loss: 1.2342 - val_mean_absolute_error: 0.4337
# Epoch 56/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.2143 - mean_absolute_error: 0.5656 - val_loss: 1.0761 - val_mean_absolute_error: 0.4223
# Epoch 57/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.1651 - mean_absolute_error: 0.5541 - val_loss: 1.0669 - val_mean_absolute_error: 0.5157
# Epoch 58/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 3.1092 - mean_absolute_error: 0.5586 - val_loss: 1.0871 - val_mean_absolute_error: 0.4215
# Epoch 59/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 3.0858 - mean_absolute_error: 0.5534 - val_loss: 1.0491 - val_mean_absolute_error: 0.4140
# Epoch 60/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.0092 - mean_absolute_error: 0.5508 - val_loss: 1.1779 - val_mean_absolute_error: 0.4212
# Epoch 61/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 3.0404 - mean_absolute_error: 0.5499 - val_loss: 1.0448 - val_mean_absolute_error: 0.4619
# Epoch 62/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 2.9812 - mean_absolute_error: 0.5510 - val_loss: 1.3589 - val_mean_absolute_error: 0.5099
# Epoch 63/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 2.9526 - mean_absolute_error: 0.5401 - val_loss: 1.1357 - val_mean_absolute_error: 0.4584
# Epoch 64/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.8559 - mean_absolute_error: 0.5397 - val_loss: 1.1752 - val_mean_absolute_error: 0.5136
# Epoch 65/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.8270 - mean_absolute_error: 0.5357 - val_loss: 1.0225 - val_mean_absolute_error: 0.4002
# Epoch 66/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 2.8221 - mean_absolute_error: 0.5406 - val_loss: 0.9978 - val_mean_absolute_error: 0.4254
# Epoch 67/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.7534 - mean_absolute_error: 0.5325 - val_loss: 0.9857 - val_mean_absolute_error: 0.3932
# Epoch 68/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 2.7694 - mean_absolute_error: 0.5295 - val_loss: 1.6057 - val_mean_absolute_error: 0.7023
# Epoch 69/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.7210 - mean_absolute_error: 0.5262 - val_loss: 0.9579 - val_mean_absolute_error: 0.4016
# Epoch 70/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 2.6829 - mean_absolute_error: 0.5300 - val_loss: 1.1344 - val_mean_absolute_error: 0.4473
# Epoch 71/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.6592 - mean_absolute_error: 0.5326 - val_loss: 0.9945 - val_mean_absolute_error: 0.4492
# Epoch 72/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.6299 - mean_absolute_error: 0.5331 - val_loss: 0.9826 - val_mean_absolute_error: 0.4579
# Epoch 73/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.6505 - mean_absolute_error: 0.5299 - val_loss: 1.2219 - val_mean_absolute_error: 0.4592
# Epoch 74/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.6163 - mean_absolute_error: 0.5382 - val_loss: 0.8907 - val_mean_absolute_error: 0.4125
# Epoch 75/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.5758 - mean_absolute_error: 0.5241 - val_loss: 1.4399 - val_mean_absolute_error: 0.6235
# Epoch 76/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 2.4722 - mean_absolute_error: 0.5216 - val_loss: 1.0256 - val_mean_absolute_error: 0.4772
# Epoch 77/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 2.4676 - mean_absolute_error: 0.5237 - val_loss: 1.1304 - val_mean_absolute_error: 0.4923
# Epoch 78/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.4958 - mean_absolute_error: 0.5225 - val_loss: 0.8538 - val_mean_absolute_error: 0.3720
# Epoch 79/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.4214 - mean_absolute_error: 0.5174 - val_loss: 1.0177 - val_mean_absolute_error: 0.4135
# Epoch 80/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 2.4189 - mean_absolute_error: 0.5252 - val_loss: 1.0415 - val_mean_absolute_error: 0.5148
# Epoch 81/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.3237 - mean_absolute_error: 0.5050 - val_loss: 0.8432 - val_mean_absolute_error: 0.3851
# Epoch 82/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.3979 - mean_absolute_error: 0.5271 - val_loss: 0.9616 - val_mean_absolute_error: 0.4202
# Epoch 83/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.3554 - mean_absolute_error: 0.5126 - val_loss: 0.8700 - val_mean_absolute_error: 0.4125
# Epoch 84/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2.3058 - mean_absolute_error: 0.5084 - val_loss: 1.0841 - val_mean_absolute_error: 0.5575
# Epoch 85/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 2.2828 - mean_absolute_error: 0.5122 - val_loss: 1.0860 - val_mean_absolute_error: 0.4962
# Epoch 86/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 2.2804 - mean_absolute_error: 0.5084 - val_loss: 1.0428 - val_mean_absolute_error: 0.4482

# %% [markdown]
# ## (3) 💻 Temel karşılaştırma

# %% [markdown]
# > ❗️ **Önemli hatırlatma** ❗️
# >
# > ***Derin Öğrenme modellerinizi ve daha genel olarak herhangi bir Makine Öğrenmesi modelini her zaman bir temel modelle karşılaştırmayı unutmayın.***
#
# 🧑🏻‍🏫 Amacımızın çalışanların 11. yıl için maaşını tahmin etmek olduğunu unutmayın. Bu bir ***Regresyon görevidir***. Hangi temel modeli oluşturabiliriz?
# 1. Geleneksel regresyon modeli durumunda, `y_test` için temel tahmin **`y_train`'in ortalamasını tahmin etmektir**... ancak bu seçenek zamanla ilgili seriler için alakasız olabilir. Teorik olarak, birinin maaşının yıllar içinde artması gerekir!
# 2. Regresyon görevi için alternatif temel tahmin **son görülen değeri tahmin etmektir**

# %% [markdown]
# ❓ **Sorular** ❓
# * 10. ve 11. yıl arasında maaşın sabit kaldığını tahmin eden temel modelin Ortalama Mutlak Hatasını hesaplayın
# * Bu temel modeli RNN'inizle karşılaştırın

# %%
import numpy as np

y_pred_baseline = X_test[:, -1, 0] 


baseline_mae = np.mean(np.abs(y_test - y_pred_baseline))

print(f"Temel Model (Son Değer) MAE: {baseline_mae:.2f}")
# Out:
# Temel Model (Son Değer) MAE: 0.60

# %% [markdown]
# 👉 Bu soruda takılırsanız, `(4) LSTM`'i deneyin ve sonra buraya geri dönün.
#
# 🧑🏻‍🏫 Gerekirse TA'ya sorun. Cevaba sadece bu soruları başarısızlıkla cevaplamaya çalıştıktan sonra bakın.
#
# <details>
#     <summary><i>Cevap</i></summary>
#
#
# ```python
# # Bir sonraki maaşı tahmin etmek için X'teki son maaşı kullanma
# y_test_baseline = X_test[:, -1, 0]
# mae_baseline = np.mean(np.abs(y_test - y_test_baseline))
# ```
#
# </details>

# %% [markdown]
# 😁 RNN'inizin temel modelden biraz daha iyi performans gösterdiğini fark etmelisiniz.

# %% [markdown]
# ## (4) 💻 LSTM: Uzun-Kısa Süreli Bellek

# %% [markdown]
# ❓ **Sorular** ❓
#
# * Aynı modeli yazın, ancak `SimpleRNN` katmanı yerine `LSTM` katmanı ile
# * Test setindeki performansınızı değerlendirin

# %%
from tensorflow.keras import layers, models, Input

 
inputs = Input(shape=(None, 3))

  
normalizer = layers.Normalization(axis=-1)
normalizer.adapt(X_train)
x = normalizer(inputs)

 
x = layers.LSTM(20, activation='tanh')(x)

 
x = layers.Dense(10, activation='relu')(x)

 
outputs = layers.Dense(1)(x)

 
lstm_model = models.Model(inputs=inputs, outputs=outputs)
lstm_model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

lstm_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, None, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization_2 (Normalization) │ (None, None, 3)        │             7 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 20)             │         1,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,148 (8.39 KB)
#  Trainable params: 2,141 (8.36 KB)
#  Non-trainable params: 7 (32.00 B)

# %% [markdown]
# 💪 LSTM, daha düşük MAE ile SimpleRNN'den biraz daha iyi performans göstermelidir.

# %% [markdown]
# 🏁 Tebrikler! Sıralı veriler üzerinde RNN eğitmeyi öğrendiniz.
#
#
# 💾 Notebook'unuzu git add/commit/push yapmayı unutmayın...
#
# 🚀 ... ve sonraki challenge'a geçin!
#
# ---
#
# <u>Not</u>: Üzerinde çalıştığınız sekanslar tamamen sahte. Benzer verileri eğitmeniz ve üretmeniz gerektiğinde, böyle bir veri setini simüle etmek için kullanılan fonksiyonları aşağıda bulabilirsiniz.

# %% [markdown]
# ## 🛠 (Yardımcı Araçlar)

# %%
def create_sequences(number):
    X, y = [], []

    for i in range(number):
        x_i, y_i = create_individual_sequence(10)
        X.append(x_i)
        y.append(y_i)

    return np.array(X), np.array(y)

def create_individual_sequence(length):
    company_sizes = []
    nb_persons = []
    salaries = []


    # Education level
    educ_level = [max(0, int(np.random.normal(10, 2)))]*length

    # Company size
    current_size = int(1 + np.random.beta(.4, 4)*500)
    for i in range(length):
        if not np.random.randint(4): # Change 1 out of 3 possibilities
            current_size = int(max(1, np.random.normal(current_size, 50)))
        company_sizes.append(current_size)

    # Number of persons
    nb_iter = np.random.beta(.15, 4)*300
    for i in range(length):
        if not np.random.randint(2): # Change 1 out of 2 possibilities
            R_1 = np.random.beta(0.5, 8)*3
            nb_iter = nb_iter + max(-2, R_1*company_sizes[i] + np.random.randint(-2, 2))
            nb_iter = max(0, nb_iter)
            nb_iter = int(min(company_sizes[i]-1, nb_iter))
        nb_persons.append(nb_iter)


    # Salary
    salary_iter = max(800, int(np.random.normal(1200, 300)+ 0.05*company_sizes[0] +  np.random.normal(40, 400)))
    salaries.append(salary_iter)
    for i in range(1, length + 1):
        R_1 = np.random.normal(100, 50)
        change_person = nb_persons[i-1] - nb_persons[i-2]
        change_company = max(0, company_sizes[i-1] - company_sizes[i-2])
        salary_iter = salary_iter + 0.05*change_company + change_person*R_1 + np.random.normal(100, 50)
        salary_iter = max(int(salary_iter), 500)

        salaries.append(salary_iter)

    y = salaries[-1]/1000
    salaries = [_/1000 for _ in salaries[:-1]]

    return np.array([salaries, nb_persons, company_sizes]).T, y

# %%
#X, y = create_sequences(25000)

#np.save('X', X.astype(np.float32))
#np.save('y', y)
